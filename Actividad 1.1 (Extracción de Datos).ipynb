# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carga desde un archivo .xlsx sin indice
df = pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')
df
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL   1.0      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE   1.0      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS   7.0        TP0007
# 3             OMAR RODRIGUEZ GOMEZ   1.0        TP0001
# 4               PÚBLICO EN GENERAL   2.0       BP00242
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1426 entries, 0 to 1425
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CVE_DOC                    1423 non-null   object
#  1   FECHA_DOC                  1423 non-null   datetime64[ns]
#  2   NOMBRE_VENDEDOR            1424 non-null   object
#  3   NOMBRE_CLIENTE             1424 non-null   object
#  4   CANT                       1419 non-null   float64
#  5   CVE_ART                    1424 non-null   object
#  6   DESCR                      1424 non-null   object
#  7   PRECIO_UNITARIO            1424 non-null   float64
#  8   COSTO_UNITARIO             1422 non-null   float64
#  9   COSTO_UNITARIO_CALCULADO   1424 non-null   float64
#  10  SUBTOTAL_PARTIDA           1422 non-null   float64
#  11  COSTO_TOTAL_CALCULADO      1426 non-null   float64
#  12  MARGEN_UNITARIO_CALCULADO  1426 non-null   float64
# ...

# %%
#Imprimir los primeros 5 registros de dataframe
df. head()
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# 0  F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 1  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
#
#    CANT   CVE_ART                                    DESCR  PRECIO_UNITARIO  \
# 0   1.0  TUE00244  TUB COBRE 5/16"ØX165MM CIRCULA1.5KW127V           434.48
# 1   1.0  TUA00028  TUA U" 5/16 ØX250MM 1200W 120V TAP1"NPT          1264.05
# 2   7.0    TP0007     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT           551.61
# 3   1.0    TP0001     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT           140.00
# 4   2.0   BP00242  BAN P INOX 115MMX235MM 1000W 127V T/TOR           172.41
#
# ...

# %%
#Filtro por nombre de vendedor, filtrado con el nombre de Diego Armando León
filtro1=df[df["NOMBRE_VENDEDOR"] == "DIEGO ARMANDO LEON DURAN"]
filtro1
# Out:
#      CVE_DOC  FECHA_DOC           NOMBRE_VENDEDOR  \
# 2     F37041 2022-01-05  DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05  DIEGO ARMANDO LEON DURAN
# 6     F37044 2022-01-05  DIEGO ARMANDO LEON DURAN
# 8     F37048 2022-01-05  DIEGO ARMANDO LEON DURAN
# 9     F37049 2022-01-05  DIEGO ARMANDO LEON DURAN
# ...      ...        ...                       ...
# 519   F38005 2022-04-27  DIEGO ARMANDO LEON DURAN
# 580   F38141 2022-05-12  DIEGO ARMANDO LEON DURAN
# 731   F38459 2022-06-24  DIEGO ARMANDO LEON DURAN
# 851   F38665 2022-07-26  DIEGO ARMANDO LEON DURAN
# 1296  F39592 2022-11-16  DIEGO ARMANDO LEON DURAN
#
#                            NOMBRE_CLIENTE  CANT   CVE_ART  \
# 2               ANA BARBARA CRUZ PALACIOS   7.0    TP0007
# 3                    OMAR RODRIGUEZ GOMEZ   1.0    TP0001
# 6     AIRBUS HELICOPTERS MEXICO QUERETARO   1.0   RP00165
# 8                      FIDEICOMISO F/1596   NaN  TUE00207
# 9                      FIDEICOMISO F/1596   NaN  TUE00207
# ...

# %%
#seleccionamos las filas consecutivas de la 4 a la 6
filtro2= df.iloc[3:7,:] #Filas consecutivas
filtro2
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6  F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
#
#                         NOMBRE_CLIENTE  CANT  CVE_ART  \
# 3                 OMAR RODRIGUEZ GOMEZ   1.0   TP0001
# 4                   PÚBLICO EN GENERAL   2.0  BP00242
# 5                   PÚBLICO EN GENERAL   2.0  BP00243
# 6  AIRBUS HELICOPTERS MEXICO QUERETARO   1.0  RP00165
#
#                                      DESCR  PRECIO_UNITARIO  COSTO_UNITARIO  \
# 3     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT           140.00           38.96
# 4  BAN P INOX 115MMX235MM 1000W 127V T/TOR           172.41          101.71
# 5    BAN P INOX 55MMX235MM 450W 127V T/TOR           237.07           49.41
# 6        REPARACION DE BATIDOR 16.6KW 440V         14000.00         5323.76
#
# ...

# %%
#Seleccionamos las filas 8, 10 y 30 de mi dataframe
filtro3=df.iloc[[8,10,30] , :]
filtro3
# Out:
#    CVE_DOC  FECHA_DOC           NOMBRE_VENDEDOR             NOMBRE_CLIENTE  \
# 8   F37048 2022-01-05  DIEGO ARMANDO LEON DURAN         FIDEICOMISO F/1596
# 10  F37050 2022-01-05  DIEGO ARMANDO LEON DURAN         FIDEICOMISO F/1596
# 30  F37083 2022-01-10            ALFREDO CANELA  PEDRO ANTONIO SOTO IBARRA
#
#     CANT   CVE_ART                                     DESCR  PRECIO_UNITARIO  \
# 8    NaN  TUE00207  TUB INCOLOY 1/2"Øx412mm J 9KW 240V PLACA          1615.00
# 10   NaN  TUE00207  TUB INCOLOY 1/2"Øx412mm J 9KW 240V PLACA          1615.00
# 30   6.0  TUE00247    TUB INOX 7/16"ØX490MM U ESP 3200W 220V           856.04
#
#     COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# 8           517.89                    517.89           1615.00
# 10          517.89                    517.89           1615.00
# 30          295.24                    295.24           5136.22
#
#     COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  MARGEN_TOTAL_CALCULADO
# ...

# %%
df1=pd.read_excel('Detalle precios y productos fabricados 2022.xlsx',index_col=3)
df1
# Out:
#                              CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# NOMBRE_CLIENTE
# PÚBLICO EN GENERAL            F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# JUAN ANTONIO RESENDIZ UGALDE  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ANA BARBARA CRUZ PALACIOS     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# OMAR RODRIGUEZ GOMEZ          F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# PÚBLICO EN GENERAL            F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...                              ...        ...                        ...
# LUIS ENRIQUE PATIÑO PEREZ     F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# LUIS ENRIQUE PATIÑO PEREZ     F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# SEVEN DAYS ALL SPORT          F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# REVUELTA MONTECARLO           F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# CPEG SOLUTIONS                F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                               CANT       CVE_ART  \
# ...

# %%
#Filtro por nombre de cliente y precio - Costo unitario
filtro4=df1.loc[["PÚBLICO EN GENERAL","OMAR RODRIGUEZ GOMEZ"],["PRECIO_UNITARIO","COSTO_UNITARIO"]]
filtro4
# Out:
#                       PRECIO_UNITARIO  COSTO_UNITARIO
# NOMBRE_CLIENTE
# PÚBLICO EN GENERAL             434.48           52.80
# PÚBLICO EN GENERAL             172.41          101.71
# PÚBLICO EN GENERAL             237.07           49.41
# PÚBLICO EN GENERAL             605.00           44.70
# PÚBLICO EN GENERAL             522.00           51.38
# ...                               ...             ...
# PÚBLICO EN GENERAL             689.63          227.18
# PÚBLICO EN GENERAL            3416.00          222.14
# PÚBLICO EN GENERAL             410.00           57.60
# PÚBLICO EN GENERAL             732.00            0.00
# OMAR RODRIGUEZ GOMEZ           140.00           38.96
#
# [95 rows x 2 columns]

# %%
#Filtro por cola
filtro5=df.head(10)
filtro5
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0  F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6  F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 7  F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 8  F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# 9  F37049 2022-01-05   DIEGO ARMANDO LEON DURAN
#
#                         NOMBRE_CLIENTE  CANT   CVE_ART  \
# 0                   PÚBLICO EN GENERAL   1.0  TUE00244
# 1         JUAN ANTONIO RESENDIZ UGALDE   1.0  TUA00028
# 2            ANA BARBARA CRUZ PALACIOS   7.0    TP0007
# 3                 OMAR RODRIGUEZ GOMEZ   1.0    TP0001
# 4                   PÚBLICO EN GENERAL   2.0   BP00242
# 5                   PÚBLICO EN GENERAL   2.0   BP00243
# ...

# %%
#Filtro con variable Sub total partida con valores mayores a 200
filtro6=df[df["SUBTOTAL_PARTIDA"]>200]
filtro6
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL   1.0      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE   1.0      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS   7.0        TP0007
# 4               PÚBLICO EN GENERAL   2.0       BP00242
# 5               PÚBLICO EN GENERAL   2.0       BP00243
# ...

# %%
#filtro Y (Variables margen total calculado mayor a 1000 y fecha igual a 2022-12-23)
filtro7=df[(df["MARGEN_TOTAL_CALCULADO"]>1000) & (df["FECHA_DOC"]== "2022-12-23")]
filtro7
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 1412  F39824 2022-12-23             ALFREDO CANELA
# 1413  F39826 2022-12-23         AARON NUÑO CORDOVA
# 1414  F39828 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1415  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1417  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1418  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1419  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                   NOMBRE_CLIENTE  CANT       CVE_ART  \
# 1412                   MEGO AFEK   1.0      TUA00325
# 1413              CPEG SOLUTIONS   5.0       RB00007
# 1414  JUAN GERARDO GUZMAN FLORES   3.0       TP00018
# ...

# %%
#Filtro o (Variables clave articulo == BL00002 o la fecha 2022-12-23)
filtro8=df[(df["CVE_ART"] == "BL00002") | (df["FECHA_DOC"]== "2022-12-23")]
filtro8
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 1081  F39146 2022-09-26             ALFREDO CANELA
# 1412  F39824 2022-12-23             ALFREDO CANELA
# 1413  F39826 2022-12-23         AARON NUÑO CORDOVA
# 1414  F39828 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1415  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1416  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1417  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1418  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1419  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                   NOMBRE_CLIENTE  CANT       CVE_ART  \
# 1081             TRILOGIQ-MEXICO   2.0       BL00002
# ...

# %%
# Filtro con variable precio unitario menor a 800 y nombre de cliente == Luis Enrique Patiño Perez
filtro9=df[(df["PRECIO_UNITARIO"]<800) & (df ["NOMBRE_CLIENTE"]=="LUIS ENRIQUE PATIÑO PEREZ")]
filtro9
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR             NOMBRE_CLIENTE  \
# 408   F37802 2022-03-31  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 409   F37802 2022-03-31  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
#
#       CANT       CVE_ART                                 DESCR  \
# 408    6.0  CS12F1040A00  CAS INOX 1/2"ØX3" 400W 127V EXT.30CM
# 409    6.0  CS12H1050A00   CAS INOX 1/2"ØX4" 500W 127V EXT30CM
# 1421   6.0  CS12F1040A00  CAS INOX 1/2"ØX3" 400W 127V EXT.30CM
# 1422   6.0  CS12H1050A00   CAS INOX 1/2"ØX4" 500W 127V EXT30CM
#
#       PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# 408             562.5           88.95                     88.95
# 409             646.6           91.21                     91.21
# ...

# %%
filtro10=df[df['COSTO_UNITARIO_CALCULADO'] > 1000]
filtro10
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 6     F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 25    F37071 2022-01-07   DIEGO ARMANDO LEON DURAN
# 40    F37102 2022-01-12             ALFREDO CANELA
# 101   F37226 2022-01-31   DIEGO ARMANDO LEON DURAN
# 102   F37230 2022-01-31             ALFREDO CANELA
# ...      ...        ...                        ...
# 1393  F39788 2022-12-19             ALFREDO CANELA
# 1407  F39815 2022-12-22             ALFREDO CANELA
# 1409  F39816 2022-12-22             ALFREDO CANELA
# 1412  F39824 2022-12-23             ALFREDO CANELA
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
#
#                            NOMBRE_CLIENTE  CANT   CVE_ART  \
# 6     AIRBUS HELICOPTERS MEXICO QUERETARO   1.0   RP00165
# 25        FRANCISCO JAVIER MEDINA SANCHEZ   3.0  TUA00009
# 40                                DEACERO   3.0  TUE00321
# 101                         SIKA MEXICANA   2.0   PT00082
# ...

# %%
filtro1.to_csv("filtro1.csv")
filtro2.to_csv("filtro2.csv")
filtro3.to_csv("filtro3.csv")
filtro4.to_csv("filtro4.csv")
filtro5.to_csv("filtro5.csv")
filtro6.to_csv("filtro6.csv")
filtro7.to_csv("filtro7.csv")
filtro8.to_csv("filtro8.csv")
filtro9.to_csv("filtro9.csv")

# %%
filtro10.to_csv("filtro10.csv")
